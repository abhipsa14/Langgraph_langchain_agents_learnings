# %% [markdown]
# ### Embedding Techniques
# Converting text into vectors

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
#
# File <frozen os>:722, in __setitem__(self, key, value)
#
# File <frozen os>:782, in check_str(value)
#
# TypeError: str expected, not NoneType

# %%
from langchain.embeddings import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
embeddings
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from langchain.embeddings import OpenAIEmbeddings
#       2 embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
#       3 embeddings
#
# ImportError: cannot import name 'OpenAIEmbeddings' from 'langchain.embeddings' (c:\Users\abhip\Desktop\learnings\Langgraph_langchain_agents_learnings\langenv\Lib\site-packages\langchain\embeddings\__init__.py)

# %%
text="This is a tutorial to learn about vectors and embeddings"
em_vectors=embeddings.embed_query(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 text="This is a tutorial to learn about vectors and embeddings"
# ----> 2 em_vectors=embeddings.embed_query(text)
#
# NameError: name 'embeddings' is not defined

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader('speech.txt')
docs=loader.load()
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content="Speech is the use of the human voice as a medium for language. Spoken language combines vowel and consonant sounds to form units of meaning like words, which belong to a language's lexicon. There are many different intentional speech acts, such as informing, declaring, asking, persuading, directing; acts may vary in various aspects like enunciation, intonation, loudness, and tempo to convey meaning. Individuals may also unintentionally communicate aspects of their social position through speech, such as sex, age, place of origin, physiological and mental condition, education, and experiences.\n\nWhile normally used to facilitate communication with others, people may also use speech without the intent to communicate. Speech may nevertheless express emotions or desires; people talk to themselves sometimes in acts that are a development of what some psychologists (e.g., Lev Votsky) have maintained is the use of silent speech in 
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
final_documents=text_splitter.split_documents(docs)
final_documents
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content="Speech is the use of the human voice as a medium for language. Spoken language combines vowel and consonant sounds to form units of meaning like words, which belong to a language's lexicon. There are many different intentional speech acts, such as informing, declaring, asking, persuading, directing; acts may vary in various aspects like enunciation, intonation, loudness, and tempo to convey meaning. Individuals may also unintentionally communicate aspects of their social position through speech,"),
#  Document(metadata={'source': 'speech.txt'}, page_content='aspects of their social position through speech, such as sex, age, place of origin, physiological and mental condition, education, and experiences.'),
# ...

# %%
## vector embeddings and vector store db
from langchain.vectorstores import Chroma
db=Chroma.from_documents(final_documents,embeddings)

# %%
## retrieving the results
query="What is the speech about?"
res=db.similarity_search(query)
print(res)
